# %% [markdown]
# ### Importar librerias

# %%
import pandas as pd
import numpy as np
import json
import matplotlib as plt

# %% [markdown]
# ### Base de datos

# %%
#Csv:
df = pd.read_csv("C:/Users/aliso/OneDrive/Escritorio/Mineria de Datos/players_stats_by_season_full_details.csv",encoding='utf8')

# %% [markdown]
# ### Visualizar datos

# %%
df.shape          # Filas , Columnas
df.head()         #Primeros 5 datos
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  672  1514  299  ...  2335      1989.0          Aug  Aug 26, 1989     6-5
# 1  624  1349  270  ...  1978      1990.0          Jul  Jul 15, 1990     6-3
# 2  627  1283  141  ...  1863      1996.0          Oct  Oct 30, 1996     6-6
# 3  685  1238   89  ...  1857      1994.0          Dec   Dec 6, 1994    6-11
# 4  546  1249  205  ...  1778      1998.0          Sep  Sep 19, 1998     6-2
#
# ...

# %%
df.columns        #Los nombres de las columnas no muestran espacios ni signos raros ya que esta en ingles
# Out:
# Index(['League', 'Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM',
#        'FGA', '3PM', '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
#        'AST', 'STL', 'BLK', 'PTS', 'birth_year', 'birth_month', 'birth_date',
#        'height', 'height_cm', 'weight', 'weight_kg', 'nationality',
#        'high_school'],
#       dtype='object')

# %%
df.dtypes       #Tipo de datos
# Out:
# League          object
# Season          object
# Stage           object
# Player          object
# Team            object
# GP               int64
# MIN            float64
# FGM              int64
# FGA              int64
# 3PM              int64
# 3PA              int64
# FTM              int64
# FTA              int64
# TOV              int64
# PF               int64
# ORB              int64
# DRB              int64
# REB              int64
# AST              int64
# STL              int64
# BLK              int64
# PTS              int64
# birth_year     float64
# birth_month     object
# birth_date      object
# height          object
# height_cm      float64
# weight         float64
# weight_kg      float64
# nationality     object
# high_school     object
# dtype: object

# %% [markdown]
# ### Datos nulos

# %%
df.isnull().any()   #Si dice TRUE hay nulos en la columna
# Out:
# League         False
# Season         False
# Stage          False
# Player         False
# Team            True
# GP             False
# MIN            False
# FGM            False
# FGA            False
# 3PM            False
# 3PA            False
# FTM            False
# FTA            False
# TOV            False
# PF             False
# ORB            False
# DRB            False
# REB            False
# AST            False
# STL            False
# BLK            False
# PTS            False
# birth_year      True
# birth_month     True
# birth_date      True
# height          True
# height_cm       True
# weight          True
# weight_kg       True
# nationality     True
# high_school     True
# dtype: bool

# %%
df.isnull().sum()       #Cantidad de nulos por columna
# Out:
# League             0
# Season             0
# Stage              0
# Player             0
# Team              11
# GP                 0
# MIN                0
# FGM                0
# FGA                0
# 3PM                0
# 3PA                0
# FTM                0
# FTA                0
# TOV                0
# PF                 0
# ORB                0
# DRB                0
# REB                0
# AST                0
# STL                0
# BLK                0
# PTS                0
# birth_year       319
# birth_month      319
# birth_date       319
# height            74
# height_cm         74
# weight          4566
# weight_kg       4566
# nationality        7
# high_school    30247
# dtype: int64

# %% [markdown]
# ### Clasificacion de datos

# %%
df.League.unique()             #Clasifica por Liga (League)
# Out:
# array(['NBA', 'Euroleague', 'Israeli-BSL', 'Argentinian-Liga-A',
#        'Australian-NBL', 'Austrian-A-Bundesliga', 'Balkan-BIL',
#        'Belarusian-BPL', 'Belgium-Scooore-League', 'Bosnian-BiH-Liga',
#        'Brazilian-NBB', 'British-BBL', 'Bulgarian-NBL', 'Canadian-NBL',
#        'Chinese-CBA', 'Croatian-A-1-Liga', 'Czech-NBL',
#        'Danish-Basketligaen', 'Estonian-Latvian-Basketball-League',
#        'Eurocup', 'FIBA-Europe-Cup', 'Finnish-Korisliiga',
#        'French-Jeep-Elite', 'Georgian-Super-Liga', 'German-BBL',
#        'Greek-HEBA-A1', 'Hungarian-NBIA', 'Italian-Lega-Basket-Serie-A',
#        'Japanese-BLeague', 'Kosovo-FBK', 'Lebanese-Division-A',
#        'Lithuanian-LKL', 'Luxembourg-Total-League',
#        'Macedonian-Superleague', 'Mexican-LNBP', 'Netherlands-DBL',
#        'New-Zealand-NBL', 'Norwegian-BLNO', 'Polish-TBL',
#        'Romanian-Divizia-A', 'Serbian-KLS', 'Slovakian-Extraliga',
#        'Slovenian-SKL', 'South-Korean-KBL', 'Spanish-ACB',
# ...

# %%
df.Team.unique()                #Clasifica por equipos (Team)
# Out:
# array(['HOU', 'POR', 'PHX', 'MIL', 'ATL', 'DAL', 'WAS', 'LAL', 'UTA',
#        'BOS', 'LAC', 'CHI', 'SAS', 'NOP', 'DEN', 'PHI', 'SAC', 'TOR',
#        'CLE', 'OKC', 'IND', 'BRK', 'NYK', 'ORL', 'MEM', 'GSW', 'MIA',
#        'CHA', 'MIN', 'DET', 'CSKA', 'KHI', 'EFE', 'FCB', 'CAJ', 'MAC',
#        'PAN', 'FEN', 'VAL', 'BAY', 'BER', 'ZVE', 'ZAL', 'ZEN', 'OLY',
#        'RMB', 'LYV', 'HAP', 'MRL', 'NAH', 'HAPJ', 'GAL', 'HAI', 'EIL',
#        'BEER', 'IRO', 'ASH', 'HISP', 'FOR', 'CAOS', 'ARG', 'WBE', 'INST',
#        'CAP', 'AAQ', 'CIC', 'SMC', 'ADA', 'OES', 'REG', 'COMU', 'CABJ',
#        'EST', 'GIM', 'PLAT', 'CDL', 'ALM', 'LUD', 'EWE', 'CRA', 'RAS',
#        'BLB', 'GOE', 'FRA', 'OLI', 'RUL', 'BC', 'BRO', 'GIE', 'HAM',
#        'TBB', 'VIE', 'KAP', 'STP', 'ASG', 'OBE', 'RAI', 'DUKE', 'VIEN',
#        'GRZ', 'IBAR', 'PEJ', 'SHKO', 'BULT', 'RAHO', 'SOZ', 'RUB', 'BOR',
#        'BSEU', 'IMP', 'RCOP', 'PRI', 'TM2', 'G93', 'BKM', 'TMY', 'LEU',
# ...

# %%
df.height_cm.unique()            #Clasificacion por estaturas (height_cm)
# Out:
# array([196., 191., 198., 211., 188., 201., 203., 208., 206., 213., 193.,
#        183., 185., 221., 216., 175., 180., 218., 178., 173., 165.,  nan,
#        170., 168., 229., 226., 224., 160., 163.])

# %% [markdown]
# Se puede clasificar de muchas formas, pero la que mas nos interesa seria por liga de los equipos ya que es el que mayor relevancia tiene

# %%
NBA = df[df['League']=='NBA']               #Hago una clasificacion en la columna de Ligas, la que sean NBA

NBA.to_csv('Solo_clase1.csv', index=False)  #se guarda la clase NBA

# %%
LNB = df[df['League']=='French-Jeep-Elite'] #Hago una clasificacion en la columna de Ligas, la que sean Liga Nacional de Baloncesto de Francia

LNB.to_csv('Solo_clase2.csv', index=False)  #se guarda la clase Liga Nacional de Baloncesto de Francia

# %%
df.drop("height", axis=1)         #Borramos la columna height que representa la estatura en pies, ya que excel los marca como fechas
                                  # de cumplaños, ademas ya tenemos otra columna que nos da la estatura pero en cm
# Out:
#       League       Season           Stage                 Player Team  GP  \
# 0        NBA  2019 - 2020  Regular_Season           James Harden  HOU  68
# 1        NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66
# 2        NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70
# 3        NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63
# 4        NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60
# ...      ...          ...             ...                    ...  ...  ..
# 53793    NBA  1999 - 2000        Playoffs            John Salley  LAL  18
# 53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR   3
# 53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET   3
# 53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX   7
# 53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR   3
#
#           MIN  FGM   FGA  3PM  ...  BLK   PTS  birth_year  birth_month  \
# ...

# %% [markdown]
# Por el momento, solo eliminaremos esa columna ya que no sabemos si las que tienen datos nulos nos serviran proximamente o si tendremos que llenarla con ceros en caso de ser necesario

# %% [markdown]
# #### Preguntas de interes
# - ¿Para que me puede servir estas agrupaciones para la práctica siguiente?
#        Nos facilita el entendimiento de los datos, ya que podemos generalizar por agrupaciones las caracteristicas con las que cuenta en vez de por cada dato.
#
# - Importancia del analisis previo de los datos antes de iniciar las modificaciones
#        Nos ayuda a saber cuales datos son importantes para la solucion a mi problema, o sea cuales datos me sirven y cuales no; tambien ayuda a saber si los datos que tenemos si estan bien, o sea que no sean nulos o que no contenga informacion relacionada con la columna.

# %% [markdown]
# Para la practica, no creemos necesario cambiarle el nombre a nuestras columnas, pero para la tarea se podria cambiar al español para facilitar un poco mas el entendimiento de la informacion

# %%
df.rename(columns={"Player":"Jugador"})       #Cambiamos el nombre de la columna player por Jugador
# Out:
#       League       Season           Stage                Jugador Team  GP  \
# 0        NBA  2019 - 2020  Regular_Season           James Harden  HOU  68
# 1        NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66
# 2        NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70
# 3        NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63
# 4        NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60
# ...      ...          ...             ...                    ...  ...  ..
# 53793    NBA  1999 - 2000        Playoffs            John Salley  LAL  18
# 53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR   3
# 53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET   3
# 53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX   7
# 53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR   3
#
#           MIN  FGM   FGA  3PM  ...   PTS  birth_year  birth_month  \
# ...

# %% [markdown]
# #### Tareas extras: (Puntos extras)
#
# - Investigar los siguientes comandos: ?df.dropna() ?df.astype
# El comando df.dropna() permite, de una forma muy conveniente, filtrar los valores de una estructura de datos pandas para dejar solo aquellos no nulos.El comando df.astype() nos permite convertir a un tipo de categoria a otra en pandas.

# %% [markdown]
# #### Realizar una tarea de preprocesamiento no mencionada en esta práctica.

# %% [markdown]
# - [df.describe](https://aprendeia.com/explorando-los-datos-con-python/)
#
# La información que nos arroja es la siguiente:
#
# “count”: se refiere al número de términos en la columna,
#
# “mean”: se refiere al valor promedio de la columna,
#
# “std”: es la desviación estándar de la columna.
#
# También se muestra los valores máximo y mínimo, así como el límite de cada uno de los cuartiles.

# %%
df.describe()         #Solo toma las columnas que no tienen caracteres, solo los que contienen numeros
# Out:
#                  GP           MIN           FGM           FGA           3PM  \
# count  53798.000000  53798.000000  53798.000000  53798.000000  53798.000000
# mean      30.365850    753.694277    113.379438    245.480613     28.503086
# std       17.840423    534.242031    100.207990    212.244452     30.692830
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%       17.000000    382.500000     48.000000    109.000000      6.000000
# 50%       29.000000    664.300000     89.000000    196.000000     20.000000
# 75%       37.000000    955.000000    145.000000    310.000000     41.000000
# max       85.000000   3485.000000    978.000000   2173.000000    402.000000
#
#                 3PA           FTM           FTA           TOV            PF  \
# count  53798.000000  53798.000000  53798.000000  53798.000000  53798.000000
# mean      80.840626     56.387356     76.140061     47.343674     70.220213
# ...

# %% [markdown]
# Observemos abajo, que para las columnas de tipo objeto, se evalúa un conjunto diferente de estadísticas, veamos de que se trata cada uno de ellos:
#
# “unique”: esto se refiere al número de objetos distintos en la columna,
#
# “top”: es el dato más frecuente que se produce,
#
# “freq”: es la cantidad de veces que aparece el objeto “top” en la columna.
#
# Algunos valores en la tabla se muestran como “NaN”, que significa “no es un número”, esto se debe a que esta métrica estadística particular no se puede calcular para ese específico tipo de datos de columna.

# %%
df.describe(include = "all")     #Toma todas las columnas y si no es numerico ingresa NaN
# Out:
#        League       Season          Stage       Player   Team            GP  \
# count   53798        53798          53798        53798  53787  53798.000000
# unique     50           21              3        14574    793           NaN
# top       NBA  2019 - 2020  International  Anton Gavel    SAS           NaN
# freq     7490         7116          46308           36    532           NaN
# mean      NaN          NaN            NaN          NaN    NaN     30.365850
# std       NaN          NaN            NaN          NaN    NaN     17.840423
# min       NaN          NaN            NaN          NaN    NaN      1.000000
# 25%       NaN          NaN            NaN          NaN    NaN     17.000000
# 50%       NaN          NaN            NaN          NaN    NaN     29.000000
# 75%       NaN          NaN            NaN          NaN    NaN     37.000000
# max       NaN          NaN            NaN          NaN    NaN     85.000000
#
# ...
